# %% [markdown]
# # Objectives
# Try to determine which news sources have the most reliable data to inform decisions in the stock market. We will be analyzing tweets from big companies such as Bloomberg, JP Morgan, and Goldman Sachs to see whether their tweets or the general sentiment of responses are correlated with increases or decreases in stock prices. We will use this as a benchmark to compare less popular sources of stock market data such as Reddit.
#
# # Data Sources
# - Twitter Kaggle Datasets
# - Yahoo Finance API
# - Twitter API
# - Reddit API
#
# # Hypothesis
# We think that the sentiment of tweets from big stock market information sources will be reliable and have a positive correlation to stock prices. Less popular sources for stock information like Reddit will be more error prone, but will provide opportunities that yield high profit. The reasoning behind this is that people trust news from companies such as Bloomberg making those bets safer, but also less profitable. Random insights from Redditors may be wrong most of the time, but may "hit the jackpot."

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns; sns.set()

import yfinance as yf
import tweepy

import nltk
from nltk.corpus import stopwords
from nltk.tokenize import TweetTokenizer
nltk.download('punkt')
nltk.download('stopwords')

from vaderSentiment.vaderSentiment import SentimentIntensityAnalyzer

import tweepy
import config

from datetime import datetime, timedelta
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\hsnmu\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package stopwords to
# [nltk_data]     C:\Users\hsnmu\AppData\Roaming\nltk_data...
# [nltk_data]   Package stopwords is already up-to-date!

# %% [markdown]
# # Exploration of [Twitter Kaggle Dataset](https://www.kaggle.com/davidwallach/financial-tweets)
# This dataset contains financial tweets regarding stocks traded on NYSE, NASDAQ, and the S&P 500.

# %%
skiprows = [730, 2835, 3057, 3112, 3193, 3204, 3254, 3519, 4077, 4086, 4087, 4498]
tweet_df = pd.read_csv('./datasets/stockerbot-export.csv', skiprows=skiprows, parse_dates=['timestamp'])

# Drop last five rows since they seem to be in a different language
tweet_df = tweet_df[:-5]
tweet_df.head()
# Out:
#                     id                                               text  \
# 0  1019696670777503700  VIDEO: “I was in my office. I was minding my o...
# 1  1019709091038548000  The price of lumber $LB_F is down 22% since hi...
# 2  1019711413798035500  Who says the American Dream is dead? https://t...
# 3  1019716662587740200  Barry Silbert is extremely optimistic on bitco...
# 4  1019718460287389700  How satellites avoid attacks and space junk wh...
#
#                   timestamp        source symbols      company_names  \
# 0 2018-07-18 21:33:26+00:00  GoldmanSachs      GS  The Goldman Sachs
# 1 2018-07-18 22:22:47+00:00    StockTwits       M             Macy's
# 2 2018-07-18 22:32:01+00:00     TheStreet     AIG           American
# 3 2018-07-18 22:52:52+00:00   MarketWatch     BTC            Bitcoin
# 4 2018-07-18 23:00:01+00:00        Forbes    ORCL             Oracle
#
#                                                  url  verified
# 0  https://twitter.com/i/web/status/1019696670777...      True
# 1  https://twitter.com/i/web/status/1019709091038...      True
# 2                            https://buff.ly/2L3kmc4      True
# 3  https://twitter.com/i/web/status/1019716662587...      True
# 4                     http://on.forbes.com/6013DqDDU      True

# %%
ax = tweet_df.company_names.value_counts().sort_values(ascending=False).head(10).plot.barh(figsize=(10, 6))
ax.set_title('Most Commonly Tweeted Stocks')
ax.set_xlabel('Number of Times Tweeted')
# Out:
# Text(0.5, 0, 'Number of Times Tweeted')

# %% [markdown]
# It is nice to see that this dataset has many tweets (around 100) for the most frequent companies. This will help us in determing the general sentiment around these companies over time to compare to stock prices. Many big names such as 21st Century Fox, Alphabet (parent company of Google), and Netflix also appear which are very established companies.

# %%
fig, (ax1, ax2) = plt.subplots(1, 2)

tweet_df.source.value_counts().head(10).plot.barh(ax=ax1, figsize=(15, 10))
ax1.set_title('Most Common Tweet Sources')
ax1.set_xlabel('Number of Times Tweeted')

tweet_df.source.value_counts().reset_index().plot(ax=ax2)
ax2.set_title('Distribution of Number of Tweets Per Source')
ax2.set_ylabel('Number of Tweets')
ax2.set_xlabel('Twitter Users')
# Out:
# Text(0.5, 0, 'Twitter Users')

# %% [markdown]
# This is also a nice feature of our data. The bar chart on the left worried me that our dataset was only going to have a few users that tweet a lot. This would create a lot of bias in any correlations we find. But if you look at the distribution graph on the right, it shows that there are only a few users who really tweet a lot; most users in this dataset only tweet a few times which gives us a better sample. Later we will try using the Twitter API to sample a lot of tweets from specific demographics of users.

# %%
ax = tweet_df.groupby([tweet_df.timestamp.dt.year, tweet_df.timestamp.dt.month])['id'].count().plot(kind='bar')
ax.set_title('Distribution of Times')
ax.set_xlabel('Year/Month')
ax.set_ylabel('Count')
# Out:
# Text(0, 0.5, 'Count')

# %% [markdown]
# The one unfortunate thing about this dataset is it primarily includes tweets from July 2018 and a few tweets it seems from February 2018. We will likely need to pull in more data using the Twitter API, but this dataset will provide a good starting place.

# %% [markdown]
# # Collecting Stock Data Through the Yahoo Finance API
# We were originally going to compare this Twitter dataset against some Kaggle stocks datasets. Given that our Twitter dataset only covers one month and the Kaggle datasets are very large, we are instead going to use the yfinance Python module to collect data for this specific month.

# %%
# Lets identify the top 30 stocks (based on frequency) from our Twitter dataset and use that with yfinance
common_tickers = tweet_df.symbols.value_counts().sort_values(ascending=False).head(30)
common_tickers.head()
# Out:
# NFLX    101
# ES      100
# HON     100
# GPS     100
# MTB     100
# Name: symbols, dtype: int64

# %%
# Queries Yahoo Finance API for these stocks on the month of July 2018
stocks_df = yf.download(tickers=list(common_tickers.index), start='2018-07-01', end='2018-07-31')
stocks_df.head()
# Out:
# [*********************100%***********************]  30 of 30 completed
#
# 3 Failed downloads:
# - OMG: No data found for this date range, symbol may be delisted
# - ARNC: Data doesn't exist for startDate = 1530417600, endDate = 1533009600
# - FOX: Data doesn't exist for startDate = 1530417600, endDate = 1533009600
#                      Adj Close                                         \
#                           ABBV       AMAT ARNC         BLK          D
# Date
# 2018-07-02 00:00:00  80.599098  43.812244  NaN  465.989349  61.225769
# 2018-07-03 00:00:00  81.031921  42.968220  NaN  458.311768  61.995003
# 2018-07-05 00:00:00  81.785034  43.582054  NaN  458.955444  62.379616
# 2018-07-06 00:00:00  83.897171  44.243843  NaN  458.684906  62.630074
# 2018-07-09 00:00:00  84.001045  44.617893  NaN  470.261902  60.894825
#
#                                                                       ...  \
#                            DFS         ES         ESS FOX        GPS  ...
# Date                                                                  ...
# 2018-07-02 00:00:00  66.760170  55.400024  220.294998 NaN  28.312382  ...
# 2018-07-03 00:00:00  66.187805  55.869362  220.294998 NaN  28.767450  ...
# 2018-07-05 00:00:00  66.225349  56.057095  222.607773 NaN  28.196383  ...
# 2018-07-06 00:00:00  66.093971  56.610909  223.838806 NaN  27.893003  ...
# 2018-07-09 00:00:00  67.576477  54.874374  222.589127 NaN  27.500397  ...
#
#                       Volume                                           \
#                         MOMO      MTB      NFLX     NTNX OMG       ON
# Date
# 2018-07-02 00:00:00  4815300   732600   8142500  2096200 NaN  4726700
# 2018-07-03 00:00:00  2118100   383100   5280300  1296300 NaN  2400500
# 2018-07-05 00:00:00  3498100   680100   8448900  2332100 NaN  7132400
# 2018-07-06 00:00:00  4059300   829500   8629600  2291100 NaN  4202200
# 2018-07-09 00:00:00  5586900  1108800  11127500  2527400 NaN  3749400
#
#
#                           PBR    SQQQ      TEL      UPS
# Date
# 2018-07-02 00:00:00  14640200  749600  1671100  2252300
# 2018-07-03 00:00:00  15707700  509200   815400  1145700
# 2018-07-05 00:00:00  21271900  841100  1521900  2866800
# 2018-07-06 00:00:00  13076300  837000   986000  2022400
# 2018-07-09 00:00:00  18007000  617600  1140300  2103600
#
# [5 rows x 180 columns]

# %% [markdown]
# # Cleaning Yahoo Finance Data

# %%
# Only want Open, Close, and Volume. Drop the rest
stocks_df.drop(['Adj Close', 'Low', 'High'], axis=1, inplace=True)

# Columns are multi-indexed, so flatten this
stocks_df.columns = ['_'.join(multi_col) for multi_col in stocks_df.columns]

# Drop FOX, OMG, and ARNC cols since we weren't able to get data for them
stocks_df.drop(list(stocks_df.filter(regex='(FOX)|(OMG)|(ARNC)$')), axis=1, inplace=True)

stocks_df.head()
# Out:
#                      Close_ABBV  Close_AMAT   Close_BLK    Close_D  Close_DFS  \
# Date
# 2018-07-02 00:00:00   93.110001   45.680000  499.519989  68.449997  71.150002
# 2018-07-03 00:00:00   93.610001   44.799999  491.290009  69.309998  70.540001
# 2018-07-05 00:00:00   94.480003   45.439999  491.980011  69.739998  70.580002
# 2018-07-06 00:00:00   96.919998   46.130001  491.690002  70.019997  70.440002
# 2018-07-09 00:00:00   97.040001   46.520000  504.100006  68.080002  72.019997
#
#                       Close_ES   Close_ESS  Close_GPS  Close_GRPN  Close_HLT  \
# Date
# 2018-07-02 00:00:00  59.020000  236.220001  31.730000   86.199997  79.300003
# 2018-07-03 00:00:00  59.520000  236.220001  32.240002   85.199997  79.449997
# 2018-07-05 00:00:00  59.720001  238.699997  31.600000   87.599998  79.690002
# 2018-07-06 00:00:00  60.310001  240.020004  31.260000   87.199997  80.559998
# 2018-07-09 00:00:00  58.459999  238.679993  30.820000   96.599998  80.940002
#
#                      ...  Volume_MHK  Volume_MOMO  Volume_MTB  Volume_NFLX  \
# Date                 ...
# 2018-07-02 00:00:00  ...      839600      4815300      732600      8142500
# 2018-07-03 00:00:00  ...      405700      2118100      383100      5280300
# 2018-07-05 00:00:00  ...      414600      3498100      680100      8448900
# 2018-07-06 00:00:00  ...      479100      4059300      829500      8629600
# 2018-07-09 00:00:00  ...      426000      5586900     1108800     11127500
#
#                      Volume_NTNX  Volume_ON  Volume_PBR  Volume_SQQQ  \
# Date
# 2018-07-02 00:00:00      2096200    4726700    14640200       749600
# 2018-07-03 00:00:00      1296300    2400500    15707700       509200
# 2018-07-05 00:00:00      2332100    7132400    21271900       841100
# 2018-07-06 00:00:00      2291100    4202200    13076300       837000
# 2018-07-09 00:00:00      2527400    3749400    18007000       617600
#
#                      Volume_TEL  Volume_UPS
# Date
# 2018-07-02 00:00:00     1671100     2252300
# 2018-07-03 00:00:00      815400     1145700
# 2018-07-05 00:00:00     1521900     2866800
# 2018-07-06 00:00:00      986000     2022400
# 2018-07-09 00:00:00     1140300     2103600
#
# [5 rows x 81 columns]

# %% [markdown]
# This is a lot easier to work with. The data is not exactly tidy since the tickers are included in column names, but this has every price lined up by the date which should make it easier to graph. When graphing, we will just use regex to select the columns corresponding to a specific ticker. Such a dataset would be tidy.

# %% [markdown]
# # NLP and Sentiment Analysis on Tweets
# Now that we have some tweets and stock price information for the corresponding time period, we can begin to do some analysis. We will start by doing some NLP on the Tweets and then we can compare them to changes in stock price over time.
#
# We will be using VADER (Valence Aware Dictionary and Sentiment Reasoner) to figure out the sentiment. This gives us a reliable way of determining sentiment without labeling our own data and generating models. This rule-based analysis tool was explicitly designed for social media data which is perfect for this scenario.

# %%
# First filter for Tweets talking about our common tickers
relevant_tickers = tweet_df[tweet_df.symbols.isin(common_tickers.index)].reset_index()

print(relevant_tickers.shape)
relevant_tickers.head()
# Out:
# (2906, 9)
#    index                   id  \
# 0      8  1019720723441635300
# 1     21  1019737727477174300
# 2     46  1016109247048945700
# 3     82  1016153595522281500
# 4    108  1016208393378283500
#
#                                                 text  \
# 0  Senate wants emergency alerts to go out throug...
# 1  Templeton and BlackRock say now's the time to ...
# 2  In 2 days I doubled my account with the option...
# 3  Weekly Recap: $HSY price moved 4.28% since pos...
# 4  $AR $CGC $DAVE $GNC $HSY $ICON $KMB $M $PEP $P...
#
#                   timestamp          source symbols        company_names  \
# 0 2018-07-18 23:09:00+00:00      TechCrunch    NFLX              Netflix
# 1 2018-07-19 00:16:34+00:00        business     BLK            BlackRock
# 2 2018-07-08 23:58:17+00:00   HarryPickens2     HSY  The Hershey Company
# 3 2018-07-09 02:54:31+00:00  aboutheoptions     HSY  The Hershey Company
# 4 2018-07-09 06:32:15+00:00    SeekingAlpha     HSY  The Hershey Company
#
#                                                  url  verified
# 0                            https://tcrn.ch/2L8DsgT      True
# 1                           https://bloom.bg/2NmXZLe      True
# 2                           http://Optionsbypros.com     False
# 3  https://twitter.com/i/web/status/1016153595522...     False
# 4  https://seekingalpha.com/article/4185993-shari...     False

# %% [markdown]
# ## Cleaning Up Tweets with NLTK

# %%
tt = TweetTokenizer()

def clean_tweet(s):
    # Removing punctuation and stop words (e.g 'the', 'is', 'which')
    return ' '.join(wd for wd in tt.tokenize(s.lower()) if wd.isalnum() and wd not in set(stopwords.words('english')))

# Sample usage
print(relevant_tickers.text[1])
print(clean_tweet(relevant_tickers.text[1]))
# Out:
# Templeton and BlackRock say now's the time to buy emerging markets https://t.co/h4z90nxqwH https://t.co/6FkVrZlu3j
# templeton blackrock say time buy emerging markets

# %%
# Now apply this cleanup to every tweet
relevant_tickers.text = relevant_tickers.text.apply(clean_tweet)
relevant_tickers.head()
# Out:
#    index                   id  \
# 0      8  1019720723441635300
# 1     21  1019737727477174300
# 2     46  1016109247048945700
# 3     82  1016153595522281500
# 4    108  1016208393378283500
#
#                                                 text  \
# 0  senate wants emergency alerts go netflix spoti...
# 1  templeton blackrock say time buy emerging markets
# 2      2 days doubled account option trades xrx mrtx
# 3  weekly recap hsy price moved since post next s...
# 4   ar cgc dave gnc hsy icon kmb pep pg rrc smrt wtw
#
#                   timestamp          source symbols        company_names  \
# 0 2018-07-18 23:09:00+00:00      TechCrunch    NFLX              Netflix
# 1 2018-07-19 00:16:34+00:00        business     BLK            BlackRock
# 2 2018-07-08 23:58:17+00:00   HarryPickens2     HSY  The Hershey Company
# 3 2018-07-09 02:54:31+00:00  aboutheoptions     HSY  The Hershey Company
# 4 2018-07-09 06:32:15+00:00    SeekingAlpha     HSY  The Hershey Company
#
#                                                  url  verified
# 0                            https://tcrn.ch/2L8DsgT      True
# 1                           https://bloom.bg/2NmXZLe      True
# 2                           http://Optionsbypros.com     False
# 3  https://twitter.com/i/web/status/1016153595522...     False
# 4  https://seekingalpha.com/article/4185993-shari...     False

# %% [markdown]
# ## Perform Sentiment Analysis with Vader

# %%
sent = SentimentIntensityAnalyzer()
relevant_tickers['sentiment'] = relevant_tickers.text.apply(lambda s: sent.polarity_scores(s)['compound'])

# a compound sentiment value is positive if >= 0.05, negative if <= -0.05, neutral if in between
relevant_tickers.head()
# Out:
#    index                   id  \
# 0      8  1019720723441635300
# 1     21  1019737727477174300
# 2     46  1016109247048945700
# 3     82  1016153595522281500
# 4    108  1016208393378283500
#
#                                                 text  \
# 0  senate wants emergency alerts go netflix spoti...
# 1  templeton blackrock say time buy emerging markets
# 2      2 days doubled account option trades xrx mrtx
# 3  weekly recap hsy price moved since post next s...
# 4   ar cgc dave gnc hsy icon kmb pep pg rrc smrt wtw
#
#                   timestamp          source symbols        company_names  \
# 0 2018-07-18 23:09:00+00:00      TechCrunch    NFLX              Netflix
# 1 2018-07-19 00:16:34+00:00        business     BLK            BlackRock
# 2 2018-07-08 23:58:17+00:00   HarryPickens2     HSY  The Hershey Company
# 3 2018-07-09 02:54:31+00:00  aboutheoptions     HSY  The Hershey Company
# 4 2018-07-09 06:32:15+00:00    SeekingAlpha     HSY  The Hershey Company
#
#                                                  url  verified  sentiment
# 0                            https://tcrn.ch/2L8DsgT      True    -0.3818
# 1                           https://bloom.bg/2NmXZLe      True     0.0000
# 2                           http://Optionsbypros.com     False     0.0000
# 3  https://twitter.com/i/web/status/1016153595522...     False    -0.2960
# 4  https://seekingalpha.com/article/4185993-shari...     False     0.0000

# %% [markdown]
# So now each tweet has a value ranging from -1 to 1 representing how positive/negative the sentiment of the tweet is. My current worry is that many of these tweets are factual in nature meaning the sentiment score will not be indicative of stock performance. Later we will try to look at other things such as Twitter replies and compare sentiment of those tweets to stock performance.

# %% [markdown]
# ## Sentiment vs Stock Price Performance
# Now lets see how these sentiments over time correlate against stock performance

# %%
fig, axs = plt.subplots(2, 3)
syms = relevant_tickers.symbols
fig.tight_layout(pad=0.25)

# Graph Sentiment vs Time for 3 companies
axs[0, 0].set_ylim([-0.8, 0.8]); axs[0, 1].set_ylim([-0.8, 0.8]); axs[0, 2].set_ylim([-0.8, 0.8])
sentiment_kwargs = {'x': 'timestamp', 'y': 'sentiment', 'figsize': (20, 16), 'ylabel': 'Sentiment', 'xlabel': 'Timestamp'}

relevant_tickers[syms == 'NFLX'].plot.line(ax=axs[0, 0], title='Netflix Sentiment', **sentiment_kwargs)
relevant_tickers[syms == 'MOMO'].plot.line(ax=axs[0, 1], title='Momo Sentiment', **sentiment_kwargs)
relevant_tickers[syms == 'HON'].plot.line(ax=axs[0, 2], title='Honeywell Intl Sentiment', **sentiment_kwargs)

# Graph stock performance vs Time for 3 companies
price_kwargs = {'xlabel': 'Timestamp', 'ylabel': 'Close Prices', 'use_index': True}

stocks_df.plot.line(y='Close_NFLX', ax=axs[1, 0], title='Netflix Close Prices', **price_kwargs)
stocks_df.plot.line(y='Close_MOMO', ax=axs[1, 1], title='Momo Close Prices', **price_kwargs)
stocks_df.plot.line(y='Close_HON', ax=axs[1, 2], title='Honeywell Intl Close Prices', **price_kwargs)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-14-0ce9a11555c6> in <module>
#       7 sentiment_kwargs = {'x': 'timestamp', 'y': 'sentiment', 'figsize': (20, 16), 'ylabel': 'Sentiment', 'xlabel': 'Timestamp'}
#       8
# ----> 9 relevant_tickers[syms == 'NFLX'].plot.line(ax=axs[0, 0], title='Netflix Sentiment', **sentiment_kwargs)
#      10 relevant_tickers[syms == 'MOMO'].plot.line(ax=axs[0, 1], title='Momo Sentiment', **sentiment_kwargs)
#      11 relevant_tickers[syms == 'HON'].plot.line(ax=axs[0, 2], title='Honeywell Intl Sentiment', **sentiment_kwargs)
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in line(self, x, y, **kwargs)
#     916             >>> lines = df.plot.line(x='pig', y='horse')
#     917         """
# --> 918         return self(kind="line", x=x, y=y, **kwargs)
#     919
#     920     def bar(self, x=None, y=None, **kwargs):
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_core.py in __call__(self, *args, **kwargs)
#     845                     data.columns = label_name
#     846
# --> 847         return plot_backend.plot(data, kind=kind, **kwargs)
#     848
#     849     __call__.__doc__ = __doc__
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\__init__.py in plot(data, kind, **kwargs)
#      59             kwargs["ax"] = getattr(ax, "left_ax", ax)
#      60     plot_obj = PLOT_CLASSES[kind](data, **kwargs)
# ---> 61     plot_obj.generate()
#      62     plot_obj.draw()
#      63     return plot_obj.result
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in generate(self)
#     261         self._compute_plot_data()
#     262         self._setup_subplots()
# --> 263         self._make_plot()
#     264         self._add_table()
#     265         self._make_legend()
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _make_plot(self)
#    1075             kwds["label"] = label
#    1076
# -> 1077             newlines = plotf(
#    1078                 ax,
#    1079                 x,
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, column_num, stacking_id, **kwds)
#    1102             cls._initialize_stacker(ax, stacking_id, len(y))
#    1103         y_values = cls._get_stacked_values(ax, stacking_id, y, kwds["label"])
# -> 1104         lines = MPLPlot._plot(ax, x, y_values, style=style, **kwds)
#    1105         cls._update_stacker(ax, stacking_id, y)
#    1106         return lines
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\converter.py in wrapper(*args, **kwargs)
#      64     def wrapper(*args, **kwargs):
#      65         with pandas_converters():
# ---> 66             return func(*args, **kwargs)
#      67
#      68     return wrapper
#
# C:\ProgramData\Anaconda3\lib\site-packages\pandas\plotting\_matplotlib\core.py in _plot(cls, ax, x, y, style, is_errorbar, **kwds)
#     654             else:
#     655                 args = (x, y)
# --> 656             return ax.plot(*args, **kwds)
#     657
#     658     def _get_index_name(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_axes.py in plot(self, scalex, scaley, data, *args, **kwargs)
#    1645         """
#    1646         kwargs = cbook.normalize_kwargs(kwargs, mlines.Line2D)
# -> 1647         lines = [*self._get_lines(*args, data=data, **kwargs)]
#    1648         for line in lines:
#    1649             self.add_line(line)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in __call__(self, *args, **kwargs)
#     214                 this += args[0],
#     215                 args = args[1:]
# --> 216             yield from self._plot_args(this, kwargs)
#     217
#     218     def get_next_color(self):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _plot_args(self, tup, kwargs)
#     361                 "2.2", message="cycling among columns of inputs with "
#     362                 "non-matching shapes is deprecated.")
# --> 363         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     364                 for j in range(max(ncx, ncy))]
#     365
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in <listcomp>(.0)
#     361                 "2.2", message="cycling among columns of inputs with "
#     362                 "non-matching shapes is deprecated.")
# --> 363         return [func(x[:, j % ncx], y[:, j % ncy], kw, kwargs)
#     364                 for j in range(max(ncx, ncy))]
#     365
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\axes\_base.py in _makeline(self, x, y, kw, kwargs)
#     253         default_dict = self._getdefaults(set(), kw)
#     254         self._setdefaults(default_dict, kw)
# --> 255         seg = mlines.Line2D(x, y, **kw)
#     256         return seg
#     257
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\lines.py in __init__(self, xdata, ydata, linewidth, linestyle, color, marker, markersize, markeredgewidth, markeredgecolor, markerfacecolor, markerfacecoloralt, fillstyle, antialiased, dash_capstyle, solid_capstyle, dash_joinstyle, solid_joinstyle, pickradius, drawstyle, markevery, **kwargs)
#     398         # update kwargs before updating data to give the caller a
#     399         # chance to init axes (and hence unit support)
# --> 400         self.update(kwargs)
#     401         self.pickradius = pickradius
#     402         self.ind_offset = 0
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in update(self, props)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in <listcomp>(.0)
#    1004
#    1005         with cbook._setattr_cm(self, eventson=False):
# -> 1006             ret = [_update_property(self, k, v) for k, v in props.items()]
#    1007
#    1008         if len(ret):
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\artist.py in _update_property(self, k, v)
#     999                 func = getattr(self, 'set_' + k, None)
#    1000                 if not callable(func):
# -> 1001                     raise AttributeError('{!r} object has no property {!r}'
#    1002                                          .format(type(self).__name__, k))
#    1003                 return func(v)
#
# AttributeError: 'Line2D' object has no property 'ylabel'

# %% [markdown]
# Unfortunately, it does not look like there is any real correlation between the sentiment and stock prices here. I hypothesize that the problem is just with our current Twitter dataset since these tweets do not contain any real sentiment, yet we are still tagging it with a sentiment value. Now let's move on to doing similar analysis but with tweets pulled in from the Twitter API to see if this remedies the issue.

# %% [markdown]
# # Twitter API
# The Kaggle Twitter dataset was interesting and provided a starting place for analysis. Since this data was already labeled with information such as the source and stocks that it mentioned, it was easy to compare against information pulled from the Yahoo Finance API. To try and find some more insight into indicators of stock performance we will use the Twitter API to get tweets that directly mention the companies we are looking at. Hopefully, this will produce more opinionated data which will make better use of our sentiment analysis

# %%
auth = tweepy.AppAuthHandler(config.api_key, config.api_secret)
api = tweepy.API(auth)

# %%
search_res = [["Company", "Symbol", "Date", "Tweet"]]
days_ago = 6
date = datetime.today()
company_handle = ["Apple", "exxonmobil", "Walmart", "cvspharmacy", "CapitalOne"]
companies = ["Apple", "Exxon", "Walmart", "CVS", "Capital One"]
tickers = ["AAPL", "XOM", "WMT", "CVS", "COF"]

# %%
for i in range(len(companies)):
    days_ago = 6
    while days_ago >= 0:
        query = "to:" + company_handle[i] + " since:" + (date - timedelta(days=days_ago)).strftime('%Y-%m-%d') + " until:" + (date - timedelta(days=days_ago-1)).strftime('%Y-%m-%d')
        tweets = api.search(q=query, lang="en", count=50)
        for twt in tweets:
            search_res.append([companies[i], tickers[i], (date - timedelta(days=days_ago)).strftime('%Y-%m-%d'), twt.text])
        days_ago = days_ago - 1
search_res
# Out:
# [['Company', 'Symbol', 'Date', 'Tweet'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple is worth more than the entire Canadian economy, yet they still cant figure out a way to make my battery last more than 5 seconds.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple Anyone having issues with their i messages not showing d'],
#  ['Apple', 'AAPL', '2020-12-10', '@Apple @RodolfoDvm9 look at this honey😱'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@apple make your :japanese_ogre: emoji better why he so hapy https://t.co/KLu0jj806e'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple let me find out y’all reading my messages without my permission.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   "@Apple My mother's watch Series 5 gave her a warning about AFib this morning. It was confirmed by Urgent Care and s… https://t.co/OhNjKavVtJ"],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple what the heck happened? I blocked someone and their calls and text are still coming through! It needs to be fixed ASAP!'],
#  ['Apple', 'AAPL', '2020-12-10', '@Apple hire this guy @ityourboyjamz'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple my daughter ❤️#Shotoniphone https://t.co/aei2ouNyRX'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple when can we expect these emojis?? https://t.co/Fa7IZzpW2f'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple calendars have Christmas and Easter automatically on them, but not Hanukkah or Yom Kippur. Interesting...'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   "@Apple So including chargers with new phones is wasteful but including a USB-C cord without the USB-C block necessary to use it isn't?"],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple must be trynna get sued again. Peoples phones just so happening to glitch when the new ones comes out.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   'RT @14StormTrooper: @Apple really improved the rear glass lol... had a case on it and it fell off a bench in locker room. Come on man 🤦🏻\u200d♂️…'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple really improved the rear glass lol... had a case on it and it fell off a bench in locker room. Come on man… https://t.co/g0NTh77HSP'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple thank u for having water resistance because i woulda ruined my phone today. but still eat the rich 😛'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple I have Dre beats fuck you respectfully'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple @AppleSupport sent a DM regarding an appointment I have with @simplymacstore tomorrow'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple the positioning of the Digital Crown on the AirPods Max is horrible.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   'RT @MsPMcKesson: @Apple I’m confused. You mean to tell me y’all added 100 emojis with this new update and we still can’t get a black family…'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple working on in-house modems yikes trying to rob QCOM like they did intel'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@apple if u wanna know what my messages say just ask me!!! u aint gotta read em before i do!'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple My son’s iPhone 6 exploded tonight &amp; set his mattress alight, we narrowly avoided a house fire.  He put it o… https://t.co/DMbCJluaFF'],
#  ['Apple', 'AAPL', '2020-12-10', '@Apple Fuck epic'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple when my family and I FaceTime with my 98 year old grandma she can’t hear, even with headphones, so we all en… https://t.co/5V0sKcVcq2'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple Air Play is the worse thing I’ve ever used!!!!!!!!!!!!! A billion dollar company and this is the crap you guys come up with.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple is there some ETA for the bugs I reported a YEAR ago in macOS Catalina… persisting even in the Big Sur?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple pls stop hiding my texts messages i look like an ass for not responding 😪'],
#  ['Apple', 'AAPL', '2020-12-10', '@Apple endorses Love Like Honey'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple Next update, marking texts as unread 👌🏼 thank you'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple why haven’t you invented a floating phone yet?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple what’s up with the glitch in my phone... not notifying me when I get a new message'],
#  ['Apple', 'AAPL', '2020-12-10', '@Apple hey send me a new phone'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple AYE BLOOD WHY ISNT THERE A PICKLE EMOJI'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple Can you send me the address of samsung'],
#  ['Apple', 'AAPL', '2020-12-10', '@Apple Pay Them'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple has to do something about these text notifications'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple so idea...you should make it so my watch can have different tones like my phone can. #ideas'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple how do I make a music list and gift it to someone?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple @AppleSupport if you don’t start sending me notifications for texts ima lose my mind. 😂😩😒😡'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple you working on an update to fix the glitch that causes my messages to randomly open and not show notifications, or nah?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple  y’all take that lor $4.99 quick ass shit 💀💀💀😂. But when I gotta issue with my iPhone I gottta wait 3 hours to get seen 💀'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple how tf y’all gone open my messages before I do ? 🤨'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple ; I don’t even need to say you know.. fix up 😡'],
#  ['Apple', 'AAPL', '2020-12-10', '@Apple fix ur notification'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple I really wanna leave FaceTime video voicemails. Can we make that happen?'],
#  ['Apple', 'AAPL', '2020-12-10', '@apple FUCK U BITCH'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple all we want is the text without all these effects on iMovie PLS'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple could you calm down with halving my volume constantly? I’m on my car Bluetooth, controlling the volume with… https://t.co/eDpZnwmt49'],
#  ['Apple',
#   'AAPL',
#   '2020-12-10',
#   '@Apple please provide a Face ID setting that recognizes the top half of my face only #MaskOn'],
#  ['Apple', 'AAPL', '2020-12-11', '@Apple HEY WTF IS WRONG WITH YOUR IPHONES'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple hey what the fuck is wrong with your iphones quickly'],
#  ['Apple', 'AAPL', '2020-12-11', '@Apple FUCK YEEEW'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple y’all need to fix the txt message notification cause im not getting notified when people txt me https://t.co/psGDhuZuaV'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@apple really missed the opportunity esp during these times to have an AR view on your head of the AirPods Max'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple the new icons in #BigSur are a downgrade. Seriously.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@apple please do better...waiting outside in a long line with winter temp. is NOT effective for customers to spend… https://t.co/0HM7j7IFMn'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple Please launch Apple credit card in  Canada!'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple if it’s not there ong stop charging me. Try again tomorrow'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@apple why my notifications don’t show up no more'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple I haven’t had my EarPods for a year and the one speaker blew...'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   'RT @nawtthebayannge: @Apple can you please include a disclaimer about how dangerous your Apple Pencil can be? I miraculously managed to sit…'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple can you please include a disclaimer about how dangerous your Apple Pencil can be? I miraculously managed to… https://t.co/90iAAkf2CL'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple "defaults write https://t.co/OCYXmCHyjd.LaunchServices LSQuarantine -bool NO"'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple I want my check for making my phone work like a android on 1 % when Its charged and no damages'],
#  ['Apple', 'AAPL', '2020-12-11', '@Apple is the worst'],
#  ['Apple', 'AAPL', '2020-12-11', '@Apple y’all crazy as hell!'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple just received my macbook back from it\'s third repair (and by "repair" I mean a 2nd new battery). SURPRISE! I… https://t.co/EHjSogkq0w'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple my friend #BeauoftheFifthColumn is raising money to buy gifts for teens in Domestic violence shelters. They… https://t.co/RmJveDqYr5'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple Worst product experience!! I missed an important meeting.. pathetic product!! iPhone 11!! https://t.co/i9rB9ntc4b'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple fix the bug in the new update! text notifications are not coming through'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple Break it and it’s fucked. The gift of Crapple.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple Telling me to reset my expensive headphones because your new “feature” does not work well is a shitty way to… https://t.co/qHoPa4zUOj'],
#  ['Apple', 'AAPL', '2020-12-11', '@apple is really trying me lately'],
#  ['Apple',
#   'AAPL',
#   '2020-12-11',
#   '@Apple
],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@Apple @AppleSupport can you tell me why if I want to put a song on my phone from my MacBook, I have to unsync and… https://t.co/CqxYPrQvWy'],
#  ['Apple', 'AAPL', '2020-12-13', '@Apple Its evolving...but backwards'],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@Apple is taking forever to ship my iPhone. Wtf. I feel another one dropping when I finally get mine 🤧'],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@Apple what have you been feeding your iPhone 12 cameras? https://t.co/ZwkGdvYjMc'],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@Apple might be one of the biggest crooks in the Cell Phone business hands down. Esp during the pandemic'],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@Apple I’ve just spent 4hrs doing tech support for an elderly relatives iPad.\n\nCan you please please introduce a fe… https://t.co/YUEum1hn2a'],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@apple Headphone Safety. Don’t want it!  DOES NOT WORK!! Bluetooth audio receiver. No fucking headphones here!!! Re… https://t.co/9b8Ge8M1Jz'],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@Apple Planning to switch,\nBut its useless without charger, at such price you please need to include charger. Spend… https://t.co/F9XgjEYvoT'],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@Apple\n\nI’m forgetting I’m in a text conversation mid conversation. \n\nI need the notifications. What settings am I… https://t.co/27Xk6HYTtG'],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@Apple So much for an appointment and 15 minute time slot just to pickup a product bought online. 20 minutes past m… https://t.co/Z3kuFQ2Yz6'],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@Apple Can this ads stop showing on YouTube.. im try to watch video'],
#  ['Apple',
#   'AAPL',
#   '2020-12-13',
#   '@Apple really need to let us delete imessages.. without it coming up that we deleted them'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple I think you can lower the price of AirPods a bit. God don’t like greed https://t.co/tBBgduVzGQ'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@apple send me a notification to download the new iOS 14 beta and I’m gonna bring Steve jobs back to show them what a disgrace you’ve become'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple claims my #password is incorrect! I’m thrilled they think so. Now I can’t do a damn thing! Good grief!… https://t.co/lJPkx24JDd'],
#  ['Apple', 'AAPL', '2020-12-14', "@Apple Ain't got no money for this..."],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   "@Apple y'all have the fix the fact that notifications aren't coming through for messages sometimes. This is ridicul… https://t.co/1vOgIG6VvH"],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple @tim_cook Better probe if any high profile politicians and businessmen had interests in the Wistron plant th… https://t.co/OeXDgRdPBI'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple @AppleSupport that should say $49.94 a month without bundling, not $30.96, that makes it sound like it’s onl… https://t.co/VTt9r4jxfz'],
#  ['Apple', 'AAPL', '2020-12-14', '@Apple  fuck https://t.co/CuSjuys3yz'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple where tf are the lesbian, bisexual and nonbinary flag emojis at???'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple I purchased a brand new MacBook Air Aug 2020. Fan hasn’t worked properly since day 1. Been overly cautious w… https://t.co/e2ACsUhyvc'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple @AppleSupport I was looking forward to try my 3 months free trial of #applefitnessplus today but i cannot re… https://t.co/6BspBFd4CM'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple store at brickell city centre give my order to someone else but me. No security. Untrusting. DISAPPOINTED'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple at what point are you going to make it possible to recognize me with a mask on?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple get it tf together having me going crazy like Taraji in acrimony thinking this nigga ain’t text me and whole time he did'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple wtf wrong with txt message notifications ?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple can you fix the bug of when you pause playing music from@your phone it immediately closes out the app instea… https://t.co/vLHpZSzdWf'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple literally stop opening my messages without me knowing. so rude'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   "@Apple Apple, after all this time why haven't you fixed the xfer of pictures from an iphone to a windows PC? It kee… https://t.co/28Uwh7M2o3"],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   "@Apple i love you but why can't i watch videos in 4k on some devices 😔"],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple I’ll pay you to make ft voicemails a thing'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@apple maybe I dnt care who that is stop trying make me store numbers'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple Very unhappy with customer service response to email complaint. Request ignored, have put it in writing now… https://t.co/KmxhaYb7d0'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   "RT @mesomeric: @apple @AppleSupport The only reason I don't use the #Apple #mail #app on #macOS is that I can't specify when it marks an #e…"],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   "@apple @AppleSupport The only reason I don't use the #Apple #mail #app on #macOS is that I can't specify when it marks an #email as read."],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@apple has shows? https://t.co/j909doGq0m https://t.co/L9zi0KNyp5'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple y’all are a fucking joke. Give me my $1k back and you can have this 12. You rushed 5G and now my phone doesn’t fucking work.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple why aren’t i getting my messages and why am I not able to use my data outside of wifi, more specifically aft… https://t.co/re4GszMo1K'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple Stop telling me when my phone hits 20 or 10 percent and let me know when we get to 4. That’s the actually cr… https://t.co/sqlnIWe9A7'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple please get rid of sound and haptics for headphones I absolutely hate it I don’t want my music automatically… https://t.co/A6zPA3lxiO'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple when will i be able to leave a FaceTime message if my call is missed? I think people want this.'],
#  ['Apple', 'AAPL', '2020-12-14', '@Apple Hello apple'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple is planning to implement new anti-tracking features on iPhone. \n\nBut they’ve delayed the roll-out due to adv… https://t.co/Pt7TEs7kbb'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple makes all these updates. When are we gonna be able to change our text bubble colors and stuff.. that’d be cool.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple I received a text of a friend’s engagement ring now all ads on apple news are engagement rings. You deserve… https://t.co/0kZU08JKos'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple my silicone case ripped I was wondering if I’m covered under my warranty?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple if my brightness is all the way down, plz keep it that way😒'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple I hope you guys are planning to add an “Unread” filter to SMS on your next update.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple Aye! I don’t know wtf y’all got going on but get it fixed, my calls not coming through, y’all reading my dam… https://t.co/ZdXUDYaJOR'],
#  ['Apple', 'AAPL', '2020-12-14', '@Apple 🍢 what is the triangle thing ??'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple can you stop opening my fucking texts before I do? https://t.co/SopKW7l0t9'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple my watch nike 3 won’t charge not even yr yet what’s up'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple Update the software for the HomePods / minis to allow the stereo paired units to play all Mac sound options.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple has the WORST customer service in history! I’ve been trying to get this one issue resolved since November an… https://t.co/Po7RvYH1UI'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple when will this be fixed? MMS is already on.  I have to weekly toggle it off and on. https://t.co/uwGsRFBJ26'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple why cant i save contacts 😭, like im texting unknown numbers that i made contacts'],
#  ['Apple', 'AAPL', '2020-12-14', '@Apple Stop opening my messages for me'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple Take this shit away. https://t.co/t2AXYjCne8'],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   "@Apple I'm so sorry for you because since died' Jobs its company come down broken down! I can sadly see that! It, unfortunately."],
#  ['Apple',
#   'AAPL',
#   '2020-12-14',
#   '@Apple I wanted to buy an iPhone 12 Pro and a new MacBook Air but you don’t have any in stock 🤷🏻\u200d♂️'],
#  ['Apple', 'AAPL', '2020-12-14', '@Apple FaceTime needs a speaker option !'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple spiked 5% after a media report indicated it may produce more #iPhones in the first half of 2021 than analysts had been expecting.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple @AppleSupport I have had it with your customer service. I am being charged GBP 19.49 for the past 4 months a… https://t.co/HbNZHD1RGB'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple so, Apple what would happen to you if you just ship one iphone 12 pro max to me in Ghana?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple you need to revise your solution for finding missing AirPods this current system don’t make no sense bruh'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple’s Fitness+ is pretty great. Love the live Watch metrics on-screen.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple competing with @onepeloton I see https://t.co/f7lvNIWoCb'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple stop fucking playing with my phone lmao'],
#  ['Apple', 'AAPL', '2020-12-15', '@Apple is so annoying I swear dawg'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple, y’all need to add the find my AirPods feature to the case. It’s time.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple can y’all update y’all overpriced product so I can atleast get txt notifications'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@apple y’all got one more time to embarrass me. Snatched my money while I wasn’t looking and made my cash app decli… https://t.co/LttoyKLRdO'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple why the fuck is my iMac Pro crashing when I am doing the most simplistic to tasks, your not only taking away… https://t.co/oA33Q5Xlsx'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple please make this an actual emoji https://t.co/GurENGfIql'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   "@Apple why would it be that everything on Apple TV works except the TV show app? It constantly spins and won't go t… https://t.co/DUclkXCv6t"],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple When other countries will have access to Fitness+?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   "@Apple pencil $100, keyboard $299 ya buggin. 😣 got them both tho y'all better hire my kid when she's old enough"],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple releases its first over the ear headphones #AirpodsMax &gt;&gt;&gt; https://t.co/mi9OFLwNgo'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple not only are you not giving me any notifications of receiving a text...you are straight up opening the conversation and all. Chill'],
#  ['Apple', 'AAPL', '2020-12-15', '@Apple get your shit together.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple Should give this guy a free iPhone of the newest model. I believe the language spoken is Portuguese but the… https://t.co/w7yoehljpA'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple yall owe me a refund these airpod pros are trash'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple I’m going with @Sony WH-1000XM4s because they are better'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple I don’t give a fuck stop sending me this shit every 15 minutes https://t.co/QYyKFtwHKI'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple make it so that i can find the airpod CASE 😐'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple just ruined my Xmas by breaking #Xcode ... I updated to Xcode 12.3 in Catalina &amp; it became unusable. It’s no… https://t.co/qh5M6Qzn8Q'],
#  ['Apple', 'AAPL', '2020-12-15', '@Apple fix yo phones'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple why the fuck are myself and so many people not receiving text message notifications'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple it’s me but I just have my mask on https://t.co/UsY8iAuhm5'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple I still can’t use it with my Apple Watch on iPad. Apple Support doesn’t know how to fix it.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple what the fuck is wrong with my phone'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple is the best 💯 (I know they spy on us but idgaf) they make life easier'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple can you please bless the world with a cornball emoji?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   "@Apple I think we can safely say your supply chain did not pay them. You should. Workers at @Apple's Wistron plant… https://t.co/XIfKqgStqq"],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple does my Apple Pencil work on a Apple Trackpad? If not, why not?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple Please share retweet 🏠4🎄 https://t.co/tcXkCqH49F'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple So Colombia had to have such a horrible customer experience through Premium resellers 😭 this is so frustrating'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple IMA NEED YALL TO FIX THAT NOT GETTING MESSAGES SHIT I SPAZZED ON HIM FOR NO REASON!!!!!!!!!!!!!'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple you can do away with the headphone auto limiting...I really don’t need your help, thanks.'],
#  ['Apple', 'AAPL', '2020-12-15', '@Apple leave my ears alone please'],
#  ['Apple', 'AAPL', '2020-12-15', '@Apple I can’t back tap to my camera😤'],
#  ['Apple', 'AAPL', '2020-12-15', '@Apple Maybe when I finish school'],
#  ['Apple', 'AAPL', '2020-12-15', '@Apple Welcome to 2012!'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple @AppStore review team just rejected an update to FreelanceStation because apparently I’m not specifically sa… https://t.co/SGE7yNgtrV'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple Please add Elliptical to your workouts!'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple Chief Keef sister Husband\n*New* Music Video\nhttps://t.co/pxY6LWDDvl'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple what’s the point of us checking auto update if NOTHING ever auto updates?? 🙄'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple is it true you cannot connect Apple fitness + to tv over AirPlay from an iOS device?  #applefitnessplus #applefitnessfail'],
#  ['Apple', 'AAPL', '2020-12-15', '@Apple \n\nFix iMessage notifications. Thx'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple I need to know when people text me TYSM!!!!!'],
#  ['Apple',
#   'AAPL',
#   '2020-12-15',
#   '@Apple might have a problem here https://t.co/aqR7aZ45wf'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple WHEN I TYPE “BLACK” STOP CORRECTING IT TO “BLANK” I WILL FIND YOU TIM'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple can you fix the message glitch where my phone is reading messages when I’m clearly not ? I know this isn’t j… https://t.co/hsN89JIHJC'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple @AppleSupport fix autocorrect. Stop changing words that don’t need to be fixed. Be better.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple finally releases their much anticipated Fitness app that will allow subscribers to do high quality video wor… https://t.co/zwdyhYIGf4'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple @AppleSupport just lost a life longer customer. 2018 MBP just stopped working mid work, causing me to possib… https://t.co/I0CCgjHfy1'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple @AppleSupport why not bring this and other services to Jamaica though, especially since you’re promoting it… https://t.co/Mtd9hvcPEI'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple we should be able to share our screens on FaceTime.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple What the heck is wrong with Messages in Big Sur???  Messages is unusable on my MacBook Pro because of the ri… https://t.co/XW76oZqtE4'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple How tf do i get a replacement case for my airpod pros.. The customer service is ass and your website is the most unhelpful thing'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple Imagine being waiter and this dumbass customer drops every drink she ordered on the table'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple presentation for their products are excellent ‼️'],
#  ['Apple', 'AAPL', '2020-12-16', '@Apple What a phone👍Good 👍👍'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple or @AppleSupport How many iPhone 12 Pro’s do you have in UK stock for the Graphite 256GB and/or 512GB?\n\nAsking for a friend...'],
#  ['Apple', 'AAPL', '2020-12-16', '@Apple y’all are so petty. Ugh'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple Hi Apple, how can I make my apps receive messages again without opening them? Now I have to open apps otherw… https://t.co/REIgX56M8I'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple @Microsoft @Facebook what was done with all the money you gave to #blm'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@apple. Thank you Apple.   Facebook accuses Apple of anticompetitive behavior over privacy changes |… https://t.co/q8stmLo5HP'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple fix yo shit, tired of not receiving text message notifications'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple Genius bars are canceled after 10 minutes, go to the web and reschedule.\n\nTranslation: my problems (schedule… https://t.co/757Jn1QfaI'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple where are my text notifications bro?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple why dont you donate some of your devices to poor people like us .'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   "@Apple Isn't it funny how we can link Wi-Fi back by swiping up on the home screen but I can't permanently closed it… https://t.co/F9iFT65teS"],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple you know I mean not why tf you not correcting mot? Tf'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple I had placed an order with ID W792321133 and the trade in did not work hence I had to cancel the order. This… https://t.co/aHbH0NfDyw'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@apple this is extremely inaccurate lmao, just sayin. Y’all gotta do better next year. https://t.co/OmG5ezDvu5'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple, if I reset my IPhone 7 will I be able to sign back in &amp; have all of my texts?'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple Do you know? I follow back in 5 seconds. \n\nTap Follow and see how fast. \n\nUnfollow me if I don’t follow back in 10 secs! 😇😈'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple - I own a MacBook Air that had a recall for duplicating spaces and keystrokes. When I called to find out how… https://t.co/QDLo9TuM5W'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple, there are Apps that are abusing the notification system for advertising purposes. Is this allowed and accep… https://t.co/gMDgwIal4Q'],
#  ['Apple', 'AAPL', '2020-12-16', '@Apple we need a pinky promise emoji'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple what are you doing with iMovie. You make a great update but then make it so that you can’t upload to YouTube? Kinda cringe'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple please apple bring back fortnite mobile 😭 epic is being dumb as fuck'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   'RT @smrutisrr: @Apple @AppleSupport my 12 Pro Max’s battery performance has been downgraded drastically within 48 hours after the OS update…'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple @tim_cook please add option to rename the apps on homescreen'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple i would like to have a word with whoever designed this assault on my eyeballs. https://t.co/6HlAQHJL4n'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple Chief Keef sister Husband\n*New* Music Video\nhttps://t.co/E5bLuahWur'],
#  ['Apple', 'AAPL', '2020-12-16', '@Apple movie day'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple has severely failed me today like wtf'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple @iPhoneTeam @AppleSupport GIVE ME BACK MY VOLUME@CONTROL! STOP TURNING DOWN MY F****** MUSIC'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple @AppleSupport my 12 Pro Max’s battery performance has been downgraded drastically within 48 hours after the… https://t.co/Pfbpy7MIHL'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   'RT @waltomatic: @Apple, I am so tired of getting my workflow disrupted because Apple Mail decides it needs to spring into the foreground st…'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple, I am so tired of getting my workflow disrupted because Apple Mail decides it needs to spring into the foreg… https://t.co/bOyXJgLZjc'],
#  ['Apple', 'AAPL', '2020-12-16', '@Apple please stop turning my music down'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple 25% off what they normally cost is still more than I can afford.'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple Ive to wait until mid jan before i can get a phone 🤔'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple Does it support underwater photography? #iPhone12'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple fix yo shit why I ain’t get no text notifications???'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple have you guys thought about a chocolate colored iPhone?🍫'],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   "@Apple and I are fighting big time. They won't let me use this picture of my face as my artist image. They keep rej… https://t.co/GkOUMAheXi"],
#  ['Apple',
#   'AAPL',
#   '2020-12-16',
#   '@Apple Apple pay your employees in Karnataka first and then roll out Ads.'],
#  ['Exxon',
#   'XOM',
#   '2020-12-10',
#   "@exxonmobil @nytimes I'm confused, was there another piece by @HirokoTabuchi which included connections between the… https://t.co/mLQOVu6pTk"],
#  ['Exxon',
#   'XOM',
#   '2020-12-10',
#   '@exxonmobil Stop poisoning the earth with fossil fuels!'],
#  ['Exxon',
#   'XOM',
#   '2020-12-10',
#   '@exxonmobil I can’t believe people think we can survive without oil and gas it’s ridiculous smh 🤦🏾\u200d♂️'],
#  ['Exxon',
#   'XOM',
#   '2020-12-10',
#   '@exxonmobil @OGCInews Too bad climate change isn’t real'],
#  ['Exxon',
# ...
#   '@Walmart has the WORST customer service. I need to change the shipping info on my @OriginalFunko 10" Superman and t… https://t.co/AZfY2BSLtC'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart Instead of a house it’s gon b fake p5 since I couldn’t buy one 🤦🏽'],
#  ['Walmart', 'WMT', '2020-12-16', '@Walmart is trash'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart just looking to get people in trouble selling glitter bomb roses\nThis is a @SourPatchKids move https://t.co/OHI2Vcxv67'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart @Walmarttech #askwalmart Are ps5s shipping soon or is it really January 7th.'],
#  ['Walmart', 'WMT', '2020-12-16', '@Walmart customer service is a joke.'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart Haha my sweet tooth is strong and I did buy them 😂'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart 🙏🏼 Most times it’s free, save money. Live better.'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart searching for a coupon code - do you have any? https://t.co/7BdFwhf7sy via @couponfollow'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart is fun today... self checkout, no bags. LONGEST LINE (note: one line, not plural) EVAR. My own fault for n… https://t.co/Dca0ozB92z'],
#  ['Walmart', 'WMT', '2020-12-16', '@Walmart @Walmart where the ps5’s at'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@walmart can suck my ass for only releasing PS5 consoles online for the scalpers to hoard #PS5gate'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart customer care literally just told me to go and get my package after it was delivered to the wrong apartmen… https://t.co/t0pUuNzk5J'],
#  ['Walmart', 'WMT', '2020-12-16', '@Walmart Kids clothing of course!'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart WHY DID YOU DO THIS https://t.co/j6WfdC4sNz'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart why does this tablet show $0.84?! If I can’t get it for .84?? That’s what is advertised, that’s what I sho… https://t.co/X6tqmvaf6y'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart  if you was Santa then I would write you a letter obviously asking for the new Xbox!'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart and @Gatik_AI  Switch to Fully Driverless Deliveries in 2021\n\n https://t.co/z4JktIC9xl'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   'RT @USDataArt: @Walmart will test driverless delivery trucks in Arkansas next year \nhttps://t.co/sZxEtth1Qk via @engadget \n@AllanSchwarb @f…'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walmart cancelled my PS5 order because I had previously ordered an Xbox. I’m MAD it doesn’t even make sense!!!!'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@walmart I’m getting annoyed by y’all 🙄 how y’all gonna send me the wrong thing ... 😒'],
#  ['Walmart',
#   'WMT',
#   '2020-12-16',
#   '@Walm
],
#  ['CVS',
#   'CVS',
#   '2020-12-10',
#   '@cvspharmacy As an update, I came back an hour later as instructed, there is still nobody else waiting for a flu sh… https://t.co/zDjUanzkTD'],
#  ['CVS', 'CVS', '2020-12-10', '@cvspharmacy is the 40% coupon coming back?'],
#  ['CVS',
#   'CVS',
#   '2020-12-10',
#   '@cvspharmacy I have had an absolutely horrible experience with your specialty pharmacy. I called AGAIN today to try… https://t.co/DmnmqGBj7N'],
#  ['CVS', 'CVS', '2020-12-11', '@cvspharmacy @SocialSpit Good!'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   "@cvspharmacy it's really great that your pharmacy doesn't order anything until they're completely out now my son ca… https://t.co/bv0SDzwUSc"],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   '@cvspharmacy will you notify me when vaccine is available?'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   '@cvspharmacy Thank you so much for sending teams out to help with the vaccine! I’m always impressed by your commitment to health!'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   '@cvspharmacy you guys definitely need more people working in the pharmacy.  On hold for 45 minutes is insane'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   'RT @honeyz_flava: @cvspharmacy\n@DoorDash\nThis is the mess we deal with, customers who report food as not delivered knowing doggone well the…'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   '@cvspharmacy @ZajaczkowskiDan I’ve seen this response several times but you haven’t addressed how it will he handle… https://t.co/oCLhd9CDY3'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   'RT @ZajaczkowskiDan: @cvspharmacy One of your managers stealing from a delivery service. \n\nhttps://t.co/9G3vIwnxWW'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   '@cvspharmacy Is this person really a manager behaving like this, seemingly committing the old eat-N-run with… https://t.co/vav28G6SHQ'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   '@cvspharmacy @SoTrumpie You guys can look this up on cams.   If she lied,  she stealing from the job too.'],
#  ['CVS', 'CVS', '2020-12-11', '@cvspharmacy Did so.'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   '@cvspharmacy the manager (today 4:00 pm EST) &amp; the usual Asian pharmacist are always full of drama avoiding having… https://t.co/mloH756y2b'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   '@cvspharmacy @SoTrumpie Glad that you guys are doing something!  I’ll be shocked if DD does!'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   '@cvspharmacy @SocialSpit This is egregious. Your employee not only committed a crime, but her clear lack of concern… https://t.co/v6MWUVDIAh'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   '@cvspharmacy One of my prescriptions was supposed to be delivered to me and is many days past its expected date and… https://t.co/OVRtfSey1g'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   'RT @madmissmattie: @cvspharmacy @SoTrumpie When she touches her mask and then touches other things without washing her hands, she can be sp…'],
#  ['CVS',
#   'CVS',
#   '2020-12-11',
#   "@cvspharmacy This part of y'alls holiday cheer: https://t.co/qEkFWHhA0o"],
#  ['CVS', 'CVS', '2020-12-11', '@cvspharmacy PLEASE stop calling'],
#  ...]

# %%
tweet_df = pd.DataFrame(search_res)
tweet_df.columns = tweet_df.iloc[0]
tweet_df = tweet_df.iloc[1:]
tweet_df["Tweet"] = tweet_df["Tweet"].apply(clean_tweet)
tweet_df["Sentiment"] = tweet_df["Tweet"].apply(lambda s: sent.polarity_scores(s)['compound'])
tweet_df
# Out:
# 0         Company Symbol        Date  \
# 1           Apple   AAPL  2020-12-10
# 2           Apple   AAPL  2020-12-10
# 3           Apple   AAPL  2020-12-10
# 4           Apple   AAPL  2020-12-10
# 5           Apple   AAPL  2020-12-10
# ...           ...    ...         ...
# 1547  Capital One    COF  2020-12-16
# 1548  Capital One    COF  2020-12-16
# 1549  Capital One    COF  2020-12-16
# 1550  Capital One    COF  2020-12-16
# 1551  Capital One    COF  2020-12-16
#
# 0                                                 Tweet  Sentiment
# 1     worth entire canadian economy yet still cant f...     0.2263
# 2                        anyone issues messages showing     0.0000
# 3                                            look honey     0.0000
# 4                                make emoji better hapy     0.4404
# 5          let find reading messages without permission     0.0000
# ...                                                 ...        ...
# 1547                            fuck im closing account    -0.5423
# 1548  give one good reason need provide ssn opt mark...     0.4404
# 1549      pleasant convo agent phone message leave revi     0.4767
# 1550  still contacted technical support account work...     0.4019
# 1551        suck top class fun homeless fuck capitalism    -0.3182
#
# [1551 rows x 5 columns]

# %%
stocks_df = yf.download(tickers=tickers, start=((tweet_df.iloc[0])["Date"]), end=(date + timedelta(days=1)).strftime('%Y-%m-%d'))
# Only want Open, Close, and Volume. Drop the rest
stocks_df.drop(['Adj Close', 'Low', 'High', 'Open', 'Volume'], axis=1, inplace=True)

# Columns are multi-indexed, so flatten this
stocks_df.columns = ['_'.join(multi_col) for multi_col in stocks_df.columns]
stocks_df["Date"] = stocks_df.index
stocks_df.index = list(range(len(stocks_df.index)))
stocks_df
# Out:
# [*********************100%***********************]  5 of 5 completed
#    Close_AAPL  Close_COF  Close_CVS   Close_WMT  Close_XOM       Date
# 0  123.239998  94.669998  72.209999  147.039993  44.009998 2020-12-10
# 1  122.410004  92.169998  71.580002  147.000000  43.799999 2020-12-11
# 2  121.779999  90.419998  69.720001  145.649994  42.220001 2020-12-14
# 3  127.879997  92.680000  69.889999  145.580002  43.040001 2020-12-15
# 4  127.809998  93.589996  69.320000  145.429993  43.700001 2020-12-16

# %%
stocks_df = pd.melt(stocks_df, id_vars=["Date"], value_vars=["Close_AAPL", "Close_COF", "Close_CVS", "Close_WMT", "Close_XOM"])
stocks_df.columns = ["Date", "Symbol", "Close"]
stocks_df["Symbol"] = stocks_df["Symbol"].apply(lambda s: s[6:])
stocks_df["Date"] = stocks_df["Date"].apply(lambda d: d.strftime('%Y-%m-%d'))
tweet_df = tweet_df.merge(stocks_df, how="left", on=["Date", "Symbol"])
tweet_df
# Out:
#           Company Symbol        Date  \
# 0           Apple   AAPL  2020-12-10
# 1           Apple   AAPL  2020-12-10
# 2           Apple   AAPL  2020-12-10
# 3           Apple   AAPL  2020-12-10
# 4           Apple   AAPL  2020-12-10
# ...           ...    ...         ...
# 1546  Capital One    COF  2020-12-16
# 1547  Capital One    COF  2020-12-16
# 1548  Capital One    COF  2020-12-16
# 1549  Capital One    COF  2020-12-16
# 1550  Capital One    COF  2020-12-16
#
#                                                   Tweet  Sentiment       Close
# 0     worth entire canadian economy yet still cant f...     0.2263  123.239998
# 1                        anyone issues messages showing     0.0000  123.239998
# 2                                            look honey     0.0000  123.239998
# 3                                make emoji better hapy     0.4404  123.239998
# 4          let find reading messages without permission     0.0000  123.239998
# ...                                                 ...        ...         ...
# 1546                            fuck im closing account    -0.5423   93.589996
# 1547  give one good reason need provide ssn opt mark...     0.4404   93.589996
# 1548      pleasant convo agent phone message leave revi     0.4767   93.589996
# 1549  still contacted technical support account work...     0.4019   93.589996
# 1550        suck top class fun homeless fuck capitalism    -0.3182   93.589996
#
# [1551 rows x 6 columns]

# %% [markdown]
# # Reddit API
# Twitter has been commonly used by large companies to report to the general public on news. We will now look at the Reddit API to see if we can generate more interesting correlations to provide insight into stock performance.
